# %%
import os

# %%
dataset_path = 'C:/Users/sajid/ANISA/Deep learning projects/Rice leaf Detection/rice_leaf_diseases'

# %%
Bacterial_leaf_blight_images = len(os.listdir(os.path.join(dataset_path, 'Bacterial leaf blight')))
Brown_spot_images = len(os.listdir(os.path.join(dataset_path, 'Brown spot')))
Leaf_smut_images = len(os.listdir(os.path.join(dataset_path, 'Leaf smut')))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 Bacterial_leaf_blight_images = len(os.listdir(os.path.join(dataset_path, 'Bacterial leaf blight')))
#       2 Brown_spot_images = len(os.listdir(os.path.join(dataset_path, 'Brown spot')))
#       3 Leaf_smut_images = len(os.listdir(os.path.join(dataset_path, 'Leaf smut')))
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:/Users/sajid/ANISA/Deep learning projects/Rice leaf Detection/rice_leaf_diseases\\Bacterial leaf blight'

# %%
print("Number of Bacterial_leaf_blight_images:", Bacterial_leaf_blight_images)
print("Number of Brown_spot_images:", Brown_spot_images)
print("Number of Leaf_smut_images:",Leaf_smut_images)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 print("Number of Bacterial_leaf_blight_images:", Bacterial_leaf_blight_images)
#       2 print("Number of Brown_spot_images:", Brown_spot_images)
#       3 print("Number of Leaf_smut_images:",Leaf_smut_images)
#
# NameError: name 'Bacterial_leaf_blight_images' is not defined

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
labels = ['Bacterial_leaf_blight', 'Brown_spot','Leaf_smut']
counts = ['Bacterial_leaf_blight_images', 'Brown_spot_images','Leaf_smut_images']

# %%
Bacterial_leaf_blight_path = os.path.join(dataset_path, 'Bacterial_leaf_blight')
Brown_spot_images_path = os.path.join(dataset_path, 'Brown_spot')
Leaf_smut_images = os.path.join(dataset_path, 'Leaf_smut')

# %%
Bacterial_leaf_blight = os.listdir(Bacterial_leaf_blight_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-4176b640d7b2> in <module>
# ----> 1 Bacterial_leaf_blight = os.listdir(Bacterial_leaf_blight_path)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:/Users/sajid/ANISA/Deep learning projects/Rice leaf Detection/rice_leaf_diseases\\Bacterial_leaf_blight'

# %%
Bacterial_leaf_blight_files = os.listdir(Bacterial_leaf_blight_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 Bacterial_leaf_blight_files = os.listdir(Bacterial_leaf_blight_path)
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C:/Users/sajid/ANISA/Deep learning projects/Rice leaf Detection/rice_leaf_diseases\\Bacterial_leaf_blight'

# %%
import cv2

# %%
fig, axes = plt.subplots(3, 3, figsize=(10, 10))
fig.suptitle('Bacterial_leaf_blight_images', fontsize=16)
axes = axes.ravel()

for i, image_file in enumerate(Bacterial_leaf_blight_path[:9]):
    image_path = os.path.join(Bacterial_leaf_blight_path, image_file)
    image = cv2.imread(image_path)
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    axes[i].imshow(image)
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[14], line 8
#       6 image_path = os.path.join(Bacterial_leaf_blight_path, image_file)
#       7 image = cv2.imread(image_path)
# ----> 8 image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
#       9 axes[i].imshow(image)
#      10 axes[i].axis('off')
#
# error: OpenCV(4.8.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:182: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
